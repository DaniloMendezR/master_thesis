# %%
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import os

import tensorflow_ranking as tfr
import tensorflow as tf
from tensorflow_serving.apis import input_pb2
import keras_tuner as kt
from keras_tuner.engine.hyperparameters import HyperParameters

PATH = os.getcwd()

# %% [markdown]
# ### FIXED VARIABLES FOR THE DATA PIPELINE CREATION

# %%
# Store the paths to files containing training and test instances.
_TRAIN_DATA_PATH = "./Dataset-tfrecords/70v30Split/train.tfrecord"
_VALID_DATA_PATH = "./Dataset-tfrecords/70v30Split/test.tfrecord"


_NAME_FEATURES = ['big_RCV', 'big_RVT', 'big_positivePartscr', 'big_negativePartscr',
                  'big_splogscr', 'big_linscr', 'big_lag1_log_ret', 'big_lag4_log_ret',
                  'big_lag1_month_log_ret'] #Name of the doc features ("doc id" and "rel" are not features)
_NUM_FEATURES = len(_NAME_FEATURES)
_LABEL_FEATURE_NAME = "rel" # The document relevance label in the tf-records.
_SIZE_FEATURE_NAME= "example_list_size" #The name of the feature that WILL BE CREATED when creating the dataset via tfr.data.build_ranking_dataset with the size of the list of examples (docs) per query

# Parameters to the scoring function.
_BATCH_SIZE = 16

# %% [markdown]
# ### CREATING INPUT PIPELINE

# %%
def create_feature_columns():
    '''
    This function specifies Features via Feature Columns: (see https://developers.googleblog.com/2017/11/introducing-tensorflow-feature-columns.html)

    Feature Columns are TensorFlow abstractions that are used to capture rich information about each feature.
    It allows for easy transformations for a diverse range of raw features and for interfacing with Estimators.
    Specifying the feature columns (and optionally, their transformaitons) is necessary to provide the parsing specifications
    to parse TFRecords.

    Consistent with our input formats for ranking, such as ELWC format, we create feature columns for context features 
    and example features.
    '''
    # We dont have context features in in our datasets (query id is not a feature)
    context_feature_columns = {}
    
    #Specifying the features that we will take from our ELWC, and their transformations (in our case all are numeric, so no transformations)
    feature_names = _NAME_FEATURES
    example_feature_columns = {
        name:
        tf.feature_column.numeric_column(name, shape=(1,), default_value=0.0)
        for name in feature_names}
    
    return context_feature_columns, example_feature_columns


def create_dataset_from_tfrecords(input_path:str,
                                  batch_sz:int,
                                  list_sz:int,
                                  shuffle:bool = False,
                                  num_epochs:int = None,
                                  data_format:str = "ELWC",
                                  compression_type:str = ''):
    '''
    Function to read ELWC tfrecords and convert them into a Ranking Dataset (dictionary of tensors) according to the parsing specs described in the next lines
    '''
    
    #Specify the TensorFlow abstractions of each feature inside context and example  dictionaries
    context_feature_columns, example_feature_columns = create_feature_columns()
    label_column = tf.feature_column.numeric_column(_LABEL_FEATURE_NAME, dtype=tf.float32, default_value=-5) #When list_sz != None, the pipeline will padd with -5 or truncate the list of examples to get to list_sz 

    #Create parsing spec dictionary from input feature_columns. The returned dictionary can be used as arg in
    #tfr.dataset.build_ranking_dataset and specifies how it should parse the document in "file_pattern" argument    
    context_feature_spec = tf.feature_column.make_parse_example_spec(context_feature_columns.values())
    example_feature_spec = tf.feature_column.make_parse_example_spec(list(example_feature_columns.values()) + [label_column])
    
    #Define the "reader_args" that we'll pass to tfr.dataset.build_ranking_dataset to specify the compression type
    _reader_arg_list = []
    if compression_type:
        assert compression_type in ["", "GZIP","ZLIB"]
        _reader_arg_list = [compression_type]

    #Build Ranking Dataset
    dataset = tfr.data.build_ranking_dataset(
        file_pattern=input_path,
        data_format=tfr.data.ELWC,
        batch_size=batch_sz, #Rate at which we read our data into our model from file
        list_size=list_sz, #Amount of docs we will take for each query - in our case we take all companies
        context_feature_spec=context_feature_spec,
        example_feature_spec=example_feature_spec,
        size_feature_name=_SIZE_FEATURE_NAME,
        reader=tf.data.TFRecordDataset,
        reader_args= _reader_arg_list,
        shuffle=shuffle, #Whether to shuffle the examples before taking them
        num_epochs=num_epochs,
        )
    
    #Define additional transformations we might want to apply to our features
    def _log1p_transform(features):
        '''
        computes elementwise log_e(|x|)*sign(x)
        '''
        transformed_feats = {
            f:tf.math.multiply(
                tf.math.log1p(
                    tf.math.abs(features[f])
                    ),
                tf.math.sign(features[f])
                )
            for f in features}
        return transformed_feats

    def _split_label_and_transform_features(features):
        label = tf.squeeze(features.pop(_LABEL_FEATURE_NAME), axis=2)
        label = tf.cast(label, tf.float32)
        size_fv = features.pop(_SIZE_FEATURE_NAME) #Separate the example_list_size feature
        features = features #_log1p_transform(features) #We won't transform the features 
        features[_SIZE_FEATURE_NAME] = size_fv #Add example_list_size back again 

        return features, label

    dataset = dataset.map(_split_label_and_transform_features)
    return dataset

# %%
train_dataset = create_dataset_from_tfrecords(_TRAIN_DATA_PATH,
                                              batch_sz=_BATCH_SIZE,
                                              list_sz=None,
                                              shuffle=False,
                                              compression_type="")

vali_dataset = create_dataset_from_tfrecords(_VALID_DATA_PATH,
                                             batch_sz=_BATCH_SIZE,
                                             list_sz=None,
                                             shuffle=False,
                                             num_epochs=1, 
                                             compression_type="")

# %% [markdown]
# ### DEFINING LOSS FUNCTION AND EVALUATION METRICS

# %%
#This loss and the evaluation functions will be passed to Keras when we build our Model

#Loss:
#Different Losses knowing that the softmax loss is representative of the ListNet apporach
_loss_obj = tfr.keras.losses.get(tfr.losses.RankingLossKey.SOFTMAX_LOSS)

# %%
# tf.feature_columns specifications can be passed to the "feature_columns" argument of our DNN Estimator, when we instanciate it 
context_feature_columns, example_feature_columns = create_feature_columns()

#Defining the model builder function with all possible hyperparameters that we will pass to Keras Tuner in order to tune the model
def model_builder(hp):
    
    #Define number of layers and units:
    hp_architecture = []
    num_layers = hp.Int('num_layers', 1, 2)
    for i in range(num_layers):
        if i == 0:
            units_1 = hp.Choice("l1_units", values=[5,7,10,12,15,20])
            hp_architecture.append(units_1)
        if i == 1:
            units_2 = hp.Choice("l2_units", values=[3,5,10])
            hp_architecture.append(units_2)
    
    #Drop out hyperparameter:
    hp_dropout = hp.Choice('dropout_rate', values=[0.0, 0.05, 0.1])
    
    # Using a pre-made (Canned) Keras estimator - DNNRankingNetwork - (See to know about Estimators: https://developers.googleblog.com/2017/09/introducing-tensorflow-datasets.html)
    ranking_network = tfr.keras.canned.DNNRankingNetwork( context_feature_columns=context_feature_columns,
                                                          example_feature_columns=example_feature_columns,
                                                          hidden_layer_dims = hp_architecture,
                                                          activation=tf.nn.relu,
                                                          dropout = hp_dropout
                                                          )
    
    #Define Optimization hyperparameters:
    hp_lr = hp.Choice('learning_rate', values=[5e-1,5e-2,1e-2])
    
    # Build ranker as a Functional Keras model.
    model = tfr.keras.model.create_keras_model(network=ranking_network,
                                               loss=_loss_obj,
                                               metrics=[tfr.keras.metrics.NDCGMetric(name='NDCG27',topn=27), tfr.keras.metrics.NDCGMetric(name='NDCG')],
                                               optimizer=tf.keras.optimizers.Adagrad(learning_rate=hp_lr),
                                               size_feature_name=_SIZE_FEATURE_NAME,)
    
    return model

# %%
LOG_DIR = f"./LOG_MODELS"

#Instantiate the tuner to perform the hypertuning
tuner2 = kt.Hyperband(model_builder,
                     objective= kt.Objective('val_NDCG27',direction='max'),
                     max_epochs=150,
                     factor=3,
                     hyperband_iterations=5, #Hyperband results will depend on the weights initialization, so we will run it 5 the search from different initialization
                     directory=LOG_DIR,
                     project_name=f"run_{dt.datetime.now().strftime('%m-%d-%Y_%H-%M-%S')}")

tuner = kt.RandomSearch(model_builder,
                     objective= kt.Objective('val_NDCG27',direction='max'),
                     max_trials=200,
                     executions_per_trial=3,
                     directory=LOG_DIR,
                     project_name=f"run_{dt.datetime.now().strftime('%m-%d-%Y_%H-%M-%S')}")


#Create callbacks to stop training early after reaching a certain value for the validation loss or validation metric.
stop_early_metric = tf.keras.callbacks.EarlyStopping(monitor='val_NDCG27', patience=15)
tensorboard = keras.callbacks.TensorBoard("./tmp/tb_logs")

# %%
#Run the hyperparameter search. The arguments for the search method are the same as those used for tf.keras.model.fit
tuner.search(train_dataset,
             validation_data=vali_dataset,
             steps_per_epoch=100,
             epochs=50,
             validation_steps=1,
             callbacks=[stop_early_metric, tensorboard])
# Out:
# Trial 198 Complete [00h 01m 00s]
# val_NDCG27: 0.6758016149202982
#
# Best val_NDCG27 So Far: 0.6758016149202982
# Total elapsed time: 03h 02m 15s
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit

# %%
# %load_ext tensorboard
# %tensorboard --logdir=./tmp/tb_logs --port 25952
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 25952 (pid 21972), started 2 days, 4:46:58 ago. (Use '!kill 21972' to kill it.)
#       <iframe id="tensorboard-frame-b6019b19998a5a5b" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b6019b19998a5a5b");
#           const url = new URL("/", window.location);
#           const port = 25952;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
best_hps.values
# Out:
# {'num_layers': 1,
#  'l1_units': 10,
#  'dropout_rate': 0.05,
#  'learning_rate': 0.5,
#  'l2_units': 10}

# %%
# Train the model
#Find the optimal number of epochs to train the model with the hyperparameters obtained from the search.

# Build the model with the optimal hyperparameters and train it on the data for 100 epochs
model = tuner.hypermodel.build(best_hps)
history = model.fit(train_dataset,
                    validation_data=vali_dataset,
                    steps_per_epoch=100,
                    epochs=200,
                    validation_steps=1)
# Out:
# Epoch 1/200
# 100/100 [==============================] - 4s 19ms/step - loss: 4.3212 - NDCG27: 0.6139 - NDCG: 0.7393 - val_loss: 4.9944 - val_NDCG27: 0.6262 - val_NDCG: 0.7603
# Epoch 2/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2100 - NDCG27: 0.6450 - NDCG: 0.7602 - val_loss: 4.9928 - val_NDCG27: 0.6228 - val_NDCG: 0.7448
# Epoch 3/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2950 - NDCG27: 0.6478 - NDCG: 0.7626 - val_loss: 4.9886 - val_NDCG27: 0.6390 - val_NDCG: 0.7635
# Epoch 4/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2295 - NDCG27: 0.6532 - NDCG: 0.7657 - val_loss: 4.9852 - val_NDCG27: 0.6643 - val_NDCG: 0.7816
# Epoch 5/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2613 - NDCG27: 0.6524 - NDCG: 0.7644 - val_loss: 4.9817 - val_NDCG27: 0.6338 - val_NDCG: 0.7557
# Epoch 6/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2429 - NDCG27: 0.6544 - NDCG: 0.7660 - val_loss: 4.9829 - val_NDCG27: 0.6737 - val_NDCG: 0.7920
# Epoch 7/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2281 - NDCG27: 0.6541 - NDCG: 0.7642 - val_loss: 4.9839 - val_NDCG27: 0.6333 - val_NDCG: 0.7559
# Epoch 8/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2896 - NDCG27: 0.6560 - NDCG: 0.7669 - val_loss: 4.9809 - val_NDCG27: 0.6393 - val_NDCG: 0.7593
# Epoch 9/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2030 - NDCG27: 0.6584 - NDCG: 0.7677 - val_loss: 4.9825 - val_NDCG27: 0.6480 - val_NDCG: 0.7596
# Epoch 10/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2874 - NDCG27: 0.6588 - NDCG: 0.7685 - val_loss: 4.9788 - val_NDCG27: 0.6396 - val_NDCG: 0.7575
# Epoch 11/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2225 - NDCG27: 0.6595 - NDCG: 0.7680 - val_loss: 4.9786 - val_NDCG27: 0.6733 - val_NDCG: 0.7930
# Epoch 12/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2700 - NDCG27: 0.6569 - NDCG: 0.7664 - val_loss: 4.9762 - val_NDCG27: 0.6525 - val_NDCG: 0.7646
# Epoch 13/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2436 - NDCG27: 0.6611 - NDCG: 0.7703 - val_loss: 4.9759 - val_NDCG27: 0.6771 - val_NDCG: 0.7936
# Epoch 14/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2213 - NDCG27: 0.6577 - NDCG: 0.7662 - val_loss: 4.9785 - val_NDCG27: 0.6633 - val_NDCG: 0.7751
# Epoch 15/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2836 - NDCG27: 0.6585 - NDCG: 0.7681 - val_loss: 4.9770 - val_NDCG27: 0.6630 - val_NDCG: 0.7731
# Epoch 16/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2069 - NDCG27: 0.6588 - NDCG: 0.7666 - val_loss: 4.9785 - val_NDCG27: 0.6750 - val_NDCG: 0.7834
# Epoch 17/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2860 - NDCG27: 0.6583 - NDCG: 0.7674 - val_loss: 4.9744 - val_NDCG27: 0.6668 - val_NDCG: 0.7799
# Epoch 18/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2164 - NDCG27: 0.6613 - NDCG: 0.7695 - val_loss: 4.9759 - val_NDCG27: 0.6834 - val_NDCG: 0.7984
# Epoch 19/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2803 - NDCG27: 0.6578 - NDCG: 0.7668 - val_loss: 4.9722 - val_NDCG27: 0.6679 - val_NDCG: 0.7803
# Epoch 20/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2312 - NDCG27: 0.6604 - NDCG: 0.7685 - val_loss: 4.9717 - val_NDCG27: 0.6823 - val_NDCG: 0.7977
# Epoch 21/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2307 - NDCG27: 0.6569 - NDCG: 0.7660 - val_loss: 4.9723 - val_NDCG27: 0.6767 - val_NDCG: 0.7868
# Epoch 22/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2659 - NDCG27: 0.6606 - NDCG: 0.7697 - val_loss: 4.9698 - val_NDCG27: 0.6736 - val_NDCG: 0.7860
# Epoch 23/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2167 - NDCG27: 0.6582 - NDCG: 0.7665 - val_loss: 4.9734 - val_NDCG27: 0.6965 - val_NDCG: 0.8067
# Epoch 24/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2815 - NDCG27: 0.6596 - NDCG: 0.7685 - val_loss: 4.9660 - val_NDCG27: 0.6679 - val_NDCG: 0.7814
# Epoch 25/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2173 - NDCG27: 0.6607 - NDCG: 0.7690 - val_loss: 4.9700 - val_NDCG27: 0.6923 - val_NDCG: 0.8019
# Epoch 26/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2859 - NDCG27: 0.6575 - NDCG: 0.7668 - val_loss: 4.9648 - val_NDCG27: 0.6946 - val_NDCG: 0.8041
# Epoch 27/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2276 - NDCG27: 0.6612 - NDCG: 0.7698 - val_loss: 4.9628 - val_NDCG27: 0.6853 - val_NDCG: 0.7960
# Epoch 28/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2399 - NDCG27: 0.6595 - NDCG: 0.7679 - val_loss: 4.9612 - val_NDCG27: 0.6947 - val_NDCG: 0.8022
# Epoch 29/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2527 - NDCG27: 0.6602 - NDCG: 0.7689 - val_loss: 4.9607 - val_NDCG27: 0.6919 - val_NDCG: 0.8033
# Epoch 30/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2156 - NDCG27: 0.6608 - NDCG: 0.7686 - val_loss: 4.9621 - val_NDCG27: 0.6892 - val_NDCG: 0.7983
# Epoch 31/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2820 - NDCG27: 0.6589 - NDCG: 0.7685 - val_loss: 4.9554 - val_NDCG27: 0.6936 - val_NDCG: 0.8019
# Epoch 32/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2177 - NDCG27: 0.6613 - NDCG: 0.7689 - val_loss: 4.9576 - val_NDCG27: 0.6932 - val_NDCG: 0.8059
# Epoch 33/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2911 - NDCG27: 0.6596 - NDCG: 0.7688 - val_loss: 4.9537 - val_NDCG27: 0.6974 - val_NDCG: 0.8043
# Epoch 34/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2162 - NDCG27: 0.6636 - NDCG: 0.7708 - val_loss: 4.9469 - val_NDCG27: 0.6945 - val_NDCG: 0.8052
# Epoch 35/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2452 - NDCG27: 0.6597 - NDCG: 0.7688 - val_loss: 4.9491 - val_NDCG27: 0.6892 - val_NDCG: 0.8026
# Epoch 36/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2615 - NDCG27: 0.6595 - NDCG: 0.7690 - val_loss: 4.9465 - val_NDCG27: 0.6962 - val_NDCG: 0.8059
# Epoch 37/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2157 - NDCG27: 0.6596 - NDCG: 0.7677 - val_loss: 4.9471 - val_NDCG27: 0.6931 - val_NDCG: 0.8043
# Epoch 38/200
# 100/100 [==============================] - 1s 9ms/step - loss: 4.2890 - NDCG27: 0.6616 - NDCG: 0.7706 - val_loss: 4.9402 - val_NDCG27: 0.6954 - val_NDCG: 0.8055
# Epoch 39/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2056 - NDCG27: 0.6625 - NDCG: 0.7702 - val_loss: 4.9415 - val_NDCG27: 0.6933 - val_NDCG: 0.8045
# Epoch 40/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2921 - NDCG27: 0.6615 - NDCG: 0.7709 - val_loss: 4.9370 - val_NDCG27: 0.6870 - val_NDCG: 0.8002
# Epoch 41/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2260 - NDCG27: 0.6611 - NDCG: 0.7698 - val_loss: 4.9331 - val_NDCG27: 0.6879 - val_NDCG: 0.8054
# Epoch 42/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2460 - NDCG27: 0.6601 - NDCG: 0.7689 - val_loss: 4.9346 - val_NDCG27: 0.6885 - val_NDCG: 0.8055
# Epoch 43/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2438 - NDCG27: 0.6623 - NDCG: 0.7710 - val_loss: 4.9305 - val_NDCG27: 0.6842 - val_NDCG: 0.8036
# Epoch 44/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2255 - NDCG27: 0.6600 - NDCG: 0.7688 - val_loss: 4.9356 - val_NDCG27: 0.6843 - val_NDCG: 0.8017
# Epoch 45/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2882 - NDCG27: 0.6617 - NDCG: 0.7708 - val_loss: 4.9288 - val_NDCG27: 0.6846 - val_NDCG: 0.8028
# Epoch 46/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.1978 - NDCG27: 0.6645 - NDCG: 0.7718 - val_loss: 4.9289 - val_NDCG27: 0.6899 - val_NDCG: 0.8067
# Epoch 47/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2891 - NDCG27: 0.6606 - NDCG: 0.7692 - val_loss: 4.9271 - val_NDCG27: 0.6928 - val_NDCG: 0.8074
# Epoch 48/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2263 - NDCG27: 0.6635 - NDCG: 0.7714 - val_loss: 4.9202 - val_NDCG27: 0.6886 - val_NDCG: 0.8067
# Epoch 49/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2596 - NDCG27: 0.6618 - NDCG: 0.7705 - val_loss: 4.9219 - val_NDCG27: 0.6934 - val_NDCG: 0.8092
# Epoch 50/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2448 - NDCG27: 0.6639 - NDCG: 0.7719 - val_loss: 4.9166 - val_NDCG27: 0.6961 - val_NDCG: 0.8111
# Epoch 51/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2176 - NDCG27: 0.6605 - NDCG: 0.7685 - val_loss: 4.9277 - val_NDCG27: 0.6988 - val_NDCG: 0.8104
# Epoch 52/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2849 - NDCG27: 0.6635 - NDCG: 0.7721 - val_loss: 4.9186 - val_NDCG27: 0.6930 - val_NDCG: 0.8077
# Epoch 53/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2026 - NDCG27: 0.6623 - NDCG: 0.7699 - val_loss: 4.9197 - val_NDCG27: 0.6985 - val_NDCG: 0.8110
# Epoch 54/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2849 - NDCG27: 0.6644 - NDCG: 0.7731 - val_loss: 4.9185 - val_NDCG27: 0.6965 - val_NDCG: 0.8105
# Epoch 55/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2170 - NDCG27: 0.6634 - NDCG: 0.7708 - val_loss: 4.9139 - val_NDCG27: 0.6995 - val_NDCG: 0.8123
# Epoch 56/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2847 - NDCG27: 0.6600 - NDCG: 0.7694 - val_loss: 4.9179 - val_NDCG27: 0.6952 - val_NDCG: 0.8111
# Epoch 57/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2271 - NDCG27: 0.6624 - NDCG: 0.7709 - val_loss: 4.9135 - val_NDCG27: 0.7069 - val_NDCG: 0.8142
# Epoch 58/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2274 - NDCG27: 0.6605 - NDCG: 0.7691 - val_loss: 4.9204 - val_NDCG27: 0.6813 - val_NDCG: 0.7947
# Epoch 59/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2704 - NDCG27: 0.6620 - NDCG: 0.7707 - val_loss: 4.9167 - val_NDCG27: 0.6937 - val_NDCG: 0.8033
# Epoch 60/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2121 - NDCG27: 0.6614 - NDCG: 0.7705 - val_loss: 4.9215 - val_NDCG27: 0.6851 - val_NDCG: 0.8007
# Epoch 61/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2840 - NDCG27: 0.6612 - NDCG: 0.7704 - val_loss: 4.9166 - val_NDCG27: 0.6982 - val_NDCG: 0.8088
# Epoch 62/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2141 - NDCG27: 0.6633 - NDCG: 0.7707 - val_loss: 4.9170 - val_NDCG27: 0.6996 - val_NDCG: 0.8083
# Epoch 63/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2853 - NDCG27: 0.6598 - NDCG: 0.7691 - val_loss: 4.9214 - val_NDCG27: 0.6775 - val_NDCG: 0.7918
# Epoch 64/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2264 - NDCG27: 0.6639 - NDCG: 0.7720 - val_loss: 4.9138 - val_NDCG27: 0.7004 - val_NDCG: 0.8076
# Epoch 65/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2314 - NDCG27: 0.6593 - NDCG: 0.7690 - val_loss: 4.9206 - val_NDCG27: 0.6809 - val_NDCG: 0.7995
# Epoch 66/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2593 - NDCG27: 0.6619 - NDCG: 0.7706 - val_loss: 4.9175 - val_NDCG27: 0.6931 - val_NDCG: 0.8058
# Epoch 67/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2146 - NDCG27: 0.6611 - NDCG: 0.7696 - val_loss: 4.9229 - val_NDCG27: 0.6897 - val_NDCG: 0.8020
# Epoch 68/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2820 - NDCG27: 0.6640 - NDCG: 0.7727 - val_loss: 4.9192 - val_NDCG27: 0.7025 - val_NDCG: 0.8075
# Epoch 69/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2122 - NDCG27: 0.6631 - NDCG: 0.7709 - val_loss: 4.9196 - val_NDCG27: 0.6902 - val_NDCG: 0.8028
# Epoch 70/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2880 - NDCG27: 0.6613 - NDCG: 0.7703 - val_loss: 4.9218 - val_NDCG27: 0.6878 - val_NDCG: 0.8016
# Epoch 71/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2211 - NDCG27: 0.6634 - NDCG: 0.7714 - val_loss: 4.9171 - val_NDCG27: 0.7069 - val_NDCG: 0.8124
# Epoch 72/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2443 - NDCG27: 0.6602 - NDCG: 0.7692 - val_loss: 4.9230 - val_NDCG27: 0.6838 - val_NDCG: 0.7995
# Epoch 73/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2543 - NDCG27: 0.6629 - NDCG: 0.7718 - val_loss: 4.9238 - val_NDCG27: 0.6897 - val_NDCG: 0.8017
# Epoch 74/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2092 - NDCG27: 0.6610 - NDCG: 0.7694 - val_loss: 4.9276 - val_NDCG27: 0.6817 - val_NDCG: 0.7931
# Epoch 75/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2943 - NDCG27: 0.6638 - NDCG: 0.7720 - val_loss: 4.9236 - val_NDCG27: 0.6938 - val_NDCG: 0.8009
# Epoch 76/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2070 - NDCG27: 0.6610 - NDCG: 0.7695 - val_loss: 4.9215 - val_NDCG27: 0.6966 - val_NDCG: 0.8060
# Epoch 77/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2902 - NDCG27: 0.6621 - NDCG: 0.7713 - val_loss: 4.9268 - val_NDCG27: 0.6889 - val_NDCG: 0.8009
# Epoch 78/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2219 - NDCG27: 0.6642 - NDCG: 0.7719 - val_loss: 4.9255 - val_NDCG27: 0.6921 - val_NDCG: 0.8047
# Epoch 79/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2475 - NDCG27: 0.6609 - NDCG: 0.7703 - val_loss: 4.9310 - val_NDCG27: 0.6835 - val_NDCG: 0.7958
# Epoch 80/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2477 - NDCG27: 0.6620 - NDCG: 0.7710 - val_loss: 4.9253 - val_NDCG27: 0.6954 - val_NDCG: 0.8053
# Epoch 81/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2119 - NDCG27: 0.6622 - NDCG: 0.7701 - val_loss: 4.9283 - val_NDCG27: 0.6999 - val_NDCG: 0.8081
# Epoch 82/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2898 - NDCG27: 0.6634 - NDCG: 0.7727 - val_loss: 4.9276 - val_NDCG27: 0.6902 - val_NDCG: 0.7991
# Epoch 83/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2038 - NDCG27: 0.6615 - NDCG: 0.7697 - val_loss: 4.9264 - val_NDCG27: 0.6899 - val_NDCG: 0.8020
# Epoch 84/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2865 - NDCG27: 0.6620 - NDCG: 0.7713 - val_loss: 4.9254 - val_NDCG27: 0.6916 - val_NDCG: 0.7995
# Epoch 85/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2267 - NDCG27: 0.6643 - NDCG: 0.7720 - val_loss: 4.9268 - val_NDCG27: 0.6911 - val_NDCG: 0.8023
# Epoch 86/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2541 - NDCG27: 0.6602 - NDCG: 0.7693 - val_loss: 4.9279 - val_NDCG27: 0.6865 - val_NDCG: 0.8000
# Epoch 87/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2439 - NDCG27: 0.6631 - NDCG: 0.7719 - val_loss: 4.9277 - val_NDCG27: 0.6873 - val_NDCG: 0.8000
# Epoch 88/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2264 - NDCG27: 0.6607 - NDCG: 0.7693 - val_loss: 4.9282 - val_NDCG27: 0.6695 - val_NDCG: 0.7784
# Epoch 89/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2811 - NDCG27: 0.6636 - NDCG: 0.7722 - val_loss: 4.9253 - val_NDCG27: 0.6880 - val_NDCG: 0.8006
# Epoch 90/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2059 - NDCG27: 0.6635 - NDCG: 0.7711 - val_loss: 4.9248 - val_NDCG27: 0.6907 - val_NDCG: 0.7999
# Epoch 91/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2789 - NDCG27: 0.6624 - NDCG: 0.7710 - val_loss: 4.9283 - val_NDCG27: 0.6696 - val_NDCG: 0.7789
# Epoch 92/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2207 - NDCG27: 0.6623 - NDCG: 0.7703 - val_loss: 4.9273 - val_NDCG27: 0.6910 - val_NDCG: 0.8019
# Epoch 93/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2710 - NDCG27: 0.6622 - NDCG: 0.7711 - val_loss: 4.9288 - val_NDCG27: 0.6832 - val_NDCG: 0.7969
# Epoch 94/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2396 - NDCG27: 0.6632 - NDCG: 0.7716 - val_loss: 4.9277 - val_NDCG27: 0.6926 - val_NDCG: 0.8022
# Epoch 95/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2149 - NDCG27: 0.6627 - NDCG: 0.7707 - val_loss: 4.9281 - val_NDCG27: 0.6837 - val_NDCG: 0.7962
# Epoch 96/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2835 - NDCG27: 0.6640 - NDCG: 0.7725 - val_loss: 4.9270 - val_NDCG27: 0.6871 - val_NDCG: 0.8008
# Epoch 97/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2080 - NDCG27: 0.6623 - NDCG: 0.7704 - val_loss: 4.9259 - val_NDCG27: 0.6884 - val_NDCG: 0.8007
# Epoch 98/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2814 - NDCG27: 0.6630 - NDCG: 0.7717 - val_loss: 4.9275 - val_NDCG27: 0.6771 - val_NDCG: 0.7843
# Epoch 99/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2154 - NDCG27: 0.6624 - NDCG: 0.7709 - val_loss: 4.9312 - val_NDCG27: 0.6852 - val_NDCG: 0.7994
# Epoch 100/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2799 - NDCG27: 0.6610 - NDCG: 0.7703 - val_loss: 4.9281 - val_NDCG27: 0.6693 - val_NDCG: 0.7837
# Epoch 101/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2262 - NDCG27: 0.6614 - NDCG: 0.7701 - val_loss: 4.9265 - val_NDCG27: 0.6964 - val_NDCG: 0.8073
# Epoch 102/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2307 - NDCG27: 0.6614 - NDCG: 0.7693 - val_loss: 4.9266 - val_NDCG27: 0.6846 - val_NDCG: 0.7960
# Epoch 103/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2671 - NDCG27: 0.6614 - NDCG: 0.7706 - val_loss: 4.9271 - val_NDCG27: 0.6905 - val_NDCG: 0.8051
# Epoch 104/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2118 - NDCG27: 0.6610 - NDCG: 0.7693 - val_loss: 4.9263 - val_NDCG27: 0.6850 - val_NDCG: 0.8011
# Epoch 105/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2803 - NDCG27: 0.6613 - NDCG: 0.7702 - val_loss: 4.9322 - val_NDCG27: 0.6651 - val_NDCG: 0.7793
# Epoch 106/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2164 - NDCG27: 0.6633 - NDCG: 0.7711 - val_loss: 4.9262 - val_NDCG27: 0.6877 - val_NDCG: 0.7999
# Epoch 107/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2823 - NDCG27: 0.6634 - NDCG: 0.7722 - val_loss: 4.9299 - val_NDCG27: 0.6687 - val_NDCG: 0.7848
# Epoch 108/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2258 - NDCG27: 0.6636 - NDCG: 0.7721 - val_loss: 4.9261 - val_NDCG27: 0.6901 - val_NDCG: 0.8006
# Epoch 109/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2398 - NDCG27: 0.6604 - NDCG: 0.7692 - val_loss: 4.9266 - val_NDCG27: 0.6870 - val_NDCG: 0.7995
# Epoch 110/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2510 - NDCG27: 0.6629 - NDCG: 0.7722 - val_loss: 4.9275 - val_NDCG27: 0.6697 - val_NDCG: 0.7827
# Epoch 111/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2160 - NDCG27: 0.6610 - NDCG: 0.7695 - val_loss: 4.9272 - val_NDCG27: 0.6849 - val_NDCG: 0.8003
# Epoch 112/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2775 - NDCG27: 0.6629 - NDCG: 0.7720 - val_loss: 4.9293 - val_NDCG27: 0.6883 - val_NDCG: 0.8006
# Epoch 113/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2203 - NDCG27: 0.6665 - NDCG: 0.7735 - val_loss: 4.9269 - val_NDCG27: 0.6864 - val_NDCG: 0.7985
# Epoch 114/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2872 - NDCG27: 0.6621 - NDCG: 0.7703 - val_loss: 4.9293 - val_NDCG27: 0.6678 - val_NDCG: 0.7845
# Epoch 115/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2145 - NDCG27: 0.6635 - NDCG: 0.7713 - val_loss: 4.9269 - val_NDCG27: 0.6958 - val_NDCG: 0.8049
# Epoch 116/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2533 - NDCG27: 0.6602 - NDCG: 0.7692 - val_loss: 4.9305 - val_NDCG27: 0.6716 - val_NDCG: 0.7851
# Epoch 117/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2569 - NDCG27: 0.6630 - NDCG: 0.7715 - val_loss: 4.9275 - val_NDCG27: 0.6920 - val_NDCG: 0.8054
# Epoch 118/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2075 - NDCG27: 0.6620 - NDCG: 0.7699 - val_loss: 4.9274 - val_NDCG27: 0.6873 - val_NDCG: 0.8009
# Epoch 119/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2863 - NDCG27: 0.6639 - NDCG: 0.7727 - val_loss: 4.9308 - val_NDCG27: 0.6759 - val_NDCG: 0.7858
# Epoch 120/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2063 - NDCG27: 0.6635 - NDCG: 0.7711 - val_loss: 4.9259 - val_NDCG27: 0.6873 - val_NDCG: 0.7984
# Epoch 121/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2899 - NDCG27: 0.6619 - NDCG: 0.7709 - val_loss: 4.9309 - val_NDCG27: 0.6706 - val_NDCG: 0.7829
# Epoch 122/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2241 - NDCG27: 0.6636 - NDCG: 0.7712 - val_loss: 4.9274 - val_NDCG27: 0.6884 - val_NDCG: 0.8012
# Epoch 123/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2514 - NDCG27: 0.6621 - NDCG: 0.7711 - val_loss: 4.9314 - val_NDCG27: 0.6662 - val_NDCG: 0.7811
# Epoch 124/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2402 - NDCG27: 0.6635 - NDCG: 0.7723 - val_loss: 4.9272 - val_NDCG27: 0.6815 - val_NDCG: 0.7958
# Epoch 125/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2250 - NDCG27: 0.6618 - NDCG: 0.7698 - val_loss: 4.9272 - val_NDCG27: 0.6925 - val_NDCG: 0.8037
# Epoch 126/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2880 - NDCG27: 0.6637 - NDCG: 0.7728 - val_loss: 4.9269 - val_NDCG27: 0.6724 - val_NDCG: 0.7854
# Epoch 127/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.1923 - NDCG27: 0.6628 - NDCG: 0.7705 - val_loss: 4.9247 - val_NDCG27: 0.6837 - val_NDCG: 0.7980
# Epoch 128/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2921 - NDCG27: 0.6613 - NDCG: 0.7704 - val_loss: 4.9278 - val_NDCG27: 0.6698 - val_NDCG: 0.7822
# Epoch 129/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2230 - NDCG27: 0.6622 - NDCG: 0.7702 - val_loss: 4.9270 - val_NDCG27: 0.6936 - val_NDCG: 0.8048
# Epoch 130/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2604 - NDCG27: 0.6617 - NDCG: 0.7709 - val_loss: 4.9294 - val_NDCG27: 0.6845 - val_NDCG: 0.7967
# Epoch 131/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2417 - NDCG27: 0.6636 - NDCG: 0.7718 - val_loss: 4.9267 - val_NDCG27: 0.6894 - val_NDCG: 0.8030
# Epoch 132/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2198 - NDCG27: 0.6617 - NDCG: 0.7701 - val_loss: 4.9276 - val_NDCG27: 0.6727 - val_NDCG: 0.7847
# Epoch 133/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2816 - NDCG27: 0.6633 - NDCG: 0.7719 - val_loss: 4.9272 - val_NDCG27: 0.6916 - val_NDCG: 0.8043
# Epoch 134/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2036 - NDCG27: 0.6631 - NDCG: 0.7708 - val_loss: 4.9258 - val_NDCG27: 0.6934 - val_NDCG: 0.8051
# Epoch 135/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2833 - NDCG27: 0.6627 - NDCG: 0.7710 - val_loss: 4.9290 - val_NDCG27: 0.6847 - val_NDCG: 0.7973
# Epoch 136/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2170 - NDCG27: 0.6635 - NDCG: 0.7712 - val_loss: 4.9267 - val_NDCG27: 0.6875 - val_NDCG: 0.8026
# Epoch 137/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2824 - NDCG27: 0.6616 - NDCG: 0.7710 - val_loss: 4.9302 - val_NDCG27: 0.6694 - val_NDCG: 0.7816
# Epoch 138/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2297 - NDCG27: 0.6636 - NDCG: 0.7715 - val_loss: 4.9281 - val_NDCG27: 0.6921 - val_NDCG: 0.8026
# Epoch 139/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2228 - NDCG27: 0.6629 - NDCG: 0.7710 - val_loss: 4.9277 - val_NDCG27: 0.6872 - val_NDCG: 0.8012
# Epoch 140/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2696 - NDCG27: 0.6629 - NDCG: 0.7718 - val_loss: 4.9280 - val_NDCG27: 0.6708 - val_NDCG: 0.7843
# Epoch 141/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2122 - NDCG27: 0.6617 - NDCG: 0.7697 - val_loss: 4.9272 - val_NDCG27: 0.6913 - val_NDCG: 0.8045
# Epoch 142/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2814 - NDCG27: 0.6623 - NDCG: 0.7704 - val_loss: 4.9298 - val_NDCG27: 0.6687 - val_NDCG: 0.7825
# Epoch 143/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2142 - NDCG27: 0.6642 - NDCG: 0.7718 - val_loss: 4.9259 - val_NDCG27: 0.6855 - val_NDCG: 0.8014
# Epoch 144/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2868 - NDCG27: 0.6601 - NDCG: 0.7693 - val_loss: 4.9306 - val_NDCG27: 0.6711 - val_NDCG: 0.7853
# Epoch 145/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2244 - NDCG27: 0.6629 - NDCG: 0.7710 - val_loss: 4.9262 - val_NDCG27: 0.6916 - val_NDCG: 0.8038
# Epoch 146/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2307 - NDCG27: 0.6607 - NDCG: 0.7695 - val_loss: 4.9292 - val_NDCG27: 0.6704 - val_NDCG: 0.7836
# Epoch 147/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2579 - NDCG27: 0.6631 - NDCG: 0.7714 - val_loss: 4.9265 - val_NDCG27: 0.6864 - val_NDCG: 0.7994
# Epoch 148/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2166 - NDCG27: 0.6616 - NDCG: 0.7695 - val_loss: 4.9269 - val_NDCG27: 0.6880 - val_NDCG: 0.8026
# Epoch 149/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2801 - NDCG27: 0.6641 - NDCG: 0.7727 - val_loss: 4.9307 - val_NDCG27: 0.6695 - val_NDCG: 0.7829
# Epoch 150/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2117 - NDCG27: 0.6651 - NDCG: 0.7723 - val_loss: 4.9254 - val_NDCG27: 0.6866 - val_NDCG: 0.8027
# Epoch 151/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2882 - NDCG27: 0.6617 - NDCG: 0.7705 - val_loss: 4.9299 - val_NDCG27: 0.6676 - val_NDCG: 0.7819
# Epoch 152/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2201 - NDCG27: 0.6649 - NDCG: 0.7731 - val_loss: 4.9263 - val_NDCG27: 0.6901 - val_NDCG: 0.8033
# Epoch 153/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2434 - NDCG27: 0.6622 - NDCG: 0.7701 - val_loss: 4.9295 - val_NDCG27: 0.6822 - val_NDCG: 0.7968
# Epoch 154/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2595 - NDCG27: 0.6613 - NDCG: 0.7705 - val_loss: 4.9265 - val_NDCG27: 0.6881 - val_NDCG: 0.8002
# Epoch 155/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2051 - NDCG27: 0.6639 - NDCG: 0.7713 - val_loss: 4.9285 - val_NDCG27: 0.6927 - val_NDCG: 0.8049
# Epoch 156/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2935 - NDCG27: 0.6632 - NDCG: 0.7722 - val_loss: 4.9281 - val_NDCG27: 0.6846 - val_NDCG: 0.7984
# Epoch 157/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2045 - NDCG27: 0.6641 - NDCG: 0.7715 - val_loss: 4.9260 - val_NDCG27: 0.6883 - val_NDCG: 0.8018
# Epoch 158/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2897 - NDCG27: 0.6626 - NDCG: 0.7711 - val_loss: 4.9297 - val_NDCG27: 0.6636 - val_NDCG: 0.7809
# Epoch 159/200
# 100/100 [==============================] - 1s 9ms/step - loss: 4.2211 - NDCG27: 0.6632 - NDCG: 0.7712 - val_loss: 4.9275 - val_NDCG27: 0.6897 - val_NDCG: 0.8022
# Epoch 160/200
# 100/100 [==============================] - 1s 10ms/step - loss: 4.2463 - NDCG27: 0.6618 - NDCG: 0.7703 - val_loss: 4.9300 - val_NDCG27: 0.6837 - val_NDCG: 0.7983
# Epoch 161/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2538 - NDCG27: 0.6624 - NDCG: 0.7716 - val_loss: 4.9281 - val_NDCG27: 0.6861 - val_NDCG: 0.8012
# Epoch 162/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2110 - NDCG27: 0.6623 - NDCG: 0.7702 - val_loss: 4.9290 - val_NDCG27: 0.6893 - val_NDCG: 0.8032
# Epoch 163/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2840 - NDCG27: 0.6630 - NDCG: 0.7718 - val_loss: 4.9290 - val_NDCG27: 0.6695 - val_NDCG: 0.7821
# Epoch 164/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2042 - NDCG27: 0.6624 - NDCG: 0.7704 - val_loss: 4.9280 - val_NDCG27: 0.6905 - val_NDCG: 0.8021
# Epoch 165/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2851 - NDCG27: 0.6632 - NDCG: 0.7714 - val_loss: 4.9287 - val_NDCG27: 0.6645 - val_NDCG: 0.7802
# Epoch 166/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2274 - NDCG27: 0.6632 - NDCG: 0.7713 - val_loss: 4.9284 - val_NDCG27: 0.6900 - val_NDCG: 0.8027
# Epoch 167/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2538 - NDCG27: 0.6619 - NDCG: 0.7707 - val_loss: 4.9307 - val_NDCG27: 0.6823 - val_NDCG: 0.7971
# Epoch 168/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2443 - NDCG27: 0.6629 - NDCG: 0.7717 - val_loss: 4.9284 - val_NDCG27: 0.6852 - val_NDCG: 0.8009
# Epoch 169/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2243 - NDCG27: 0.6608 - NDCG: 0.7694 - val_loss: 4.9289 - val_NDCG27: 0.6834 - val_NDCG: 0.7981
# Epoch 170/200
# 100/100 [==============================] - 1s 5ms/step - loss: 4.2845 - NDCG27: 0.6638 - NDCG: 0.7724 - val_loss: 4.9286 - val_NDCG27: 0.6888 - val_NDCG: 0.8011
# Epoch 171/200
# 100/100 [==============================] - 1s 5ms/step - loss: 4.2011 - NDCG27: 0.6637 - NDCG: 0.7715 - val_loss: 4.9272 - val_NDCG27: 0.6896 - val_NDCG: 0.8009
# Epoch 172/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2782 - NDCG27: 0.6636 - NDCG: 0.7723 - val_loss: 4.9281 - val_NDCG27: 0.6688 - val_NDCG: 0.7831
# Epoch 173/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2206 - NDCG27: 0.6640 - NDCG: 0.7718 - val_loss: 4.9276 - val_NDCG27: 0.6871 - val_NDCG: 0.8019
# Epoch 174/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2771 - NDCG27: 0.6634 - NDCG: 0.7717 - val_loss: 4.9322 - val_NDCG27: 0.6829 - val_NDCG: 0.7981
# Epoch 175/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2341 - NDCG27: 0.6639 - NDCG: 0.7716 - val_loss: 4.9286 - val_NDCG27: 0.6885 - val_NDCG: 0.8020
# Epoch 176/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2204 - NDCG27: 0.6607 - NDCG: 0.7690 - val_loss: 4.9304 - val_NDCG27: 0.6890 - val_NDCG: 0.8012
# Epoch 177/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2781 - NDCG27: 0.6629 - NDCG: 0.7722 - val_loss: 4.9289 - val_NDCG27: 0.6848 - val_NDCG: 0.7998
# Epoch 178/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2075 - NDCG27: 0.6618 - NDCG: 0.7696 - val_loss: 4.9274 - val_NDCG27: 0.6866 - val_NDCG: 0.8024
# Epoch 179/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2803 - NDCG27: 0.6643 - NDCG: 0.7727 - val_loss: 4.9297 - val_NDCG27: 0.6669 - val_NDCG: 0.7817
# Epoch 180/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2161 - NDCG27: 0.6636 - NDCG: 0.7708 - val_loss: 4.9277 - val_NDCG27: 0.6843 - val_NDCG: 0.8021
# Epoch 181/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2825 - NDCG27: 0.6594 - NDCG: 0.7688 - val_loss: 4.9296 - val_NDCG27: 0.6656 - val_NDCG: 0.7821
# Epoch 182/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2260 - NDCG27: 0.6634 - NDCG: 0.7714 - val_loss: 4.9276 - val_NDCG27: 0.6882 - val_NDCG: 0.8023
# Epoch 183/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2293 - NDCG27: 0.6610 - NDCG: 0.7692 - val_loss: 4.9289 - val_NDCG27: 0.6848 - val_NDCG: 0.7977
# Epoch 184/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2628 - NDCG27: 0.6609 - NDCG: 0.7699 - val_loss: 4.9277 - val_NDCG27: 0.6841 - val_NDCG: 0.7998
# Epoch 185/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2130 - NDCG27: 0.6611 - NDCG: 0.7691 - val_loss: 4.9266 - val_NDCG27: 0.6907 - val_NDCG: 0.8021
# Epoch 186/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2814 - NDCG27: 0.6635 - NDCG: 0.7721 - val_loss: 4.9294 - val_NDCG27: 0.6880 - val_NDCG: 0.8013
# Epoch 187/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2134 - NDCG27: 0.6621 - NDCG: 0.7704 - val_loss: 4.9270 - val_NDCG27: 0.6876 - val_NDCG: 0.8022
# Epoch 188/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2851 - NDCG27: 0.6629 - NDCG: 0.7710 - val_loss: 4.9307 - val_NDCG27: 0.6640 - val_NDCG: 0.7804
# Epoch 189/200
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2241 - NDCG27: 0.6627 - NDCG: 0.7714 - val_loss: 4.9286 - val_NDCG27: 0.6874 - val_NDCG: 0.8029
# Epoch 190/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2381 - NDCG27: 0.6605 - NDCG: 0.7696 - val_loss: 4.9288 - val_NDCG27: 0.6614 - val_NDCG: 0.7807
# Epoch 191/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2518 - NDCG27: 0.6629 - NDCG: 0.7715 - val_loss: 4.9293 - val_NDCG27: 0.6878 - val_NDCG: 0.8002
# Epoch 192/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2181 - NDCG27: 0.6615 - NDCG: 0.7698 - val_loss: 4.9293 - val_NDCG27: 0.6882 - val_NDCG: 0.7988
# Epoch 193/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2747 - NDCG27: 0.6636 - NDCG: 0.7719 - val_loss: 4.9308 - val_NDCG27: 0.6695 - val_NDCG: 0.7827
# Epoch 194/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2209 - NDCG27: 0.6640 - NDCG: 0.7713 - val_loss: 4.9267 - val_NDCG27: 0.6854 - val_NDCG: 0.8014
# Epoch 195/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2872 - NDCG27: 0.6619 - NDCG: 0.7707 - val_loss: 4.9292 - val_NDCG27: 0.6649 - val_NDCG: 0.7813
# Epoch 196/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2123 - NDCG27: 0.6645 - NDCG: 0.7718 - val_loss: 4.9303 - val_NDCG27: 0.6866 - val_NDCG: 0.8012
# Epoch 197/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2554 - NDCG27: 0.6610 - NDCG: 0.7702 - val_loss: 4.9315 - val_NDCG27: 0.6831 - val_NDCG: 0.7979
# Epoch 198/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2552 - NDCG27: 0.6614 - NDCG: 0.7709 - val_loss: 4.9291 - val_NDCG27: 0.6861 - val_NDCG: 0.8004
# Epoch 199/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2062 - NDCG27: 0.6619 - NDCG: 0.7692 - val_loss: 4.9294 - val_NDCG27: 0.6853 - val_NDCG: 0.7996
# Epoch 200/200
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2930 - NDCG27: 0.6647 - NDCG: 0.7730 - val_loss: 4.9304 - val_NDCG27: 0.6840 - val_NDCG: 0.7977

# %%
val_NDCG_per_epoch = history.history['val_NDCG27']
best_epoch = val_NDCG_per_epoch.index(max(val_NDCG_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Best epoch: 108

# %%
fig, ax = plt.subplots(figsize = (12,8))
plt.plot(history.history['NDCG27'][:125])
plt.plot(history.history['val_NDCG27'][:125])
plt.title('Model NDCG27')
plt.ylabel('NDCG27')
plt.xlabel('Epoch')
plt.legend(['Training','Validation'],loc='upper left')
plt.savefig('Evaluation.png')

# %%
#Re-instantiate the hypermodel and train it with the optimal number of epochs from above.
hypermodel = tuner.hypermodel.build(best_hps)

# Retrain the model
hyperhistory = hypermodel.fit(train_dataset,
               validation_data=vali_dataset,
               steps_per_epoch=100,
               epochs=best_epoch,
               validation_steps=1)
# Out:
# Epoch 1/57
# 100/100 [==============================] - 5s 20ms/step - loss: 4.3188 - NDCG27: 0.6161 - NDCG: 0.7415 - val_loss: 4.9822 - val_NDCG27: 0.6238 - val_NDCG: 0.7597
# Epoch 2/57
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2125 - NDCG27: 0.6383 - NDCG: 0.7553 - val_loss: 4.9916 - val_NDCG27: 0.6135 - val_NDCG: 0.7489
# Epoch 3/57
# 100/100 [==============================] - 1s 5ms/step - loss: 4.2970 - NDCG27: 0.6405 - NDCG: 0.7571 - val_loss: 4.9905 - val_NDCG27: 0.6192 - val_NDCG: 0.7550
# Epoch 4/57
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2317 - NDCG27: 0.6475 - NDCG: 0.7621 - val_loss: 4.9901 - val_NDCG27: 0.6576 - val_NDCG: 0.7876
# Epoch 5/57
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2632 - NDCG27: 0.6488 - NDCG: 0.7624 - val_loss: 4.9865 - val_NDCG27: 0.6244 - val_NDCG: 0.7620
# Epoch 6/57
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2452 - NDCG27: 0.6514 - NDCG: 0.7645 - val_loss: 4.9856 - val_NDCG27: 0.6379 - val_NDCG: 0.7649
# Epoch 7/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2308 - NDCG27: 0.6495 - NDCG: 0.7619 - val_loss: 4.9875 - val_NDCG27: 0.6305 - val_NDCG: 0.7512
# Epoch 8/57
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2918 - NDCG27: 0.6521 - NDCG: 0.7646 - val_loss: 4.9842 - val_NDCG27: 0.6360 - val_NDCG: 0.7589
# Epoch 9/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2053 - NDCG27: 0.6523 - NDCG: 0.7637 - val_loss: 4.9855 - val_NDCG27: 0.6389 - val_NDCG: 0.7570
# Epoch 10/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2900 - NDCG27: 0.6536 - NDCG: 0.7654 - val_loss: 4.9834 - val_NDCG27: 0.6357 - val_NDCG: 0.7545
# Epoch 11/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2253 - NDCG27: 0.6545 - NDCG: 0.7658 - val_loss: 4.9829 - val_NDCG27: 0.6643 - val_NDCG: 0.7792
# Epoch 12/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2715 - NDCG27: 0.6539 - NDCG: 0.7652 - val_loss: 4.9794 - val_NDCG27: 0.6570 - val_NDCG: 0.7746
# Epoch 13/57
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2459 - NDCG27: 0.6546 - NDCG: 0.7663 - val_loss: 4.9788 - val_NDCG27: 0.6666 - val_NDCG: 0.7820
# Epoch 14/57
# 100/100 [==============================] - 1s 11ms/step - loss: 4.2231 - NDCG27: 0.6541 - NDCG: 0.7651 - val_loss: 4.9802 - val_NDCG27: 0.6620 - val_NDCG: 0.7807
# Epoch 15/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2853 - NDCG27: 0.6557 - NDCG: 0.7668 - val_loss: 4.9793 - val_NDCG27: 0.6557 - val_NDCG: 0.7740
# Epoch 16/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2084 - NDCG27: 0.6552 - NDCG: 0.7647 - val_loss: 4.9800 - val_NDCG27: 0.6762 - val_NDCG: 0.7882
# Epoch 17/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2873 - NDCG27: 0.6565 - NDCG: 0.7673 - val_loss: 4.9756 - val_NDCG27: 0.6609 - val_NDCG: 0.7765
# Epoch 18/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2184 - NDCG27: 0.6553 - NDCG: 0.7657 - val_loss: 4.9754 - val_NDCG27: 0.6767 - val_NDCG: 0.7868
# Epoch 19/57
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2817 - NDCG27: 0.6554 - NDCG: 0.7658 - val_loss: 4.9737 - val_NDCG27: 0.6609 - val_NDCG: 0.7797
# Epoch 20/57
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2327 - NDCG27: 0.6576 - NDCG: 0.7676 - val_loss: 4.9712 - val_NDCG27: 0.6946 - val_NDCG: 0.8031
# Epoch 21/57
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2317 - NDCG27: 0.6558 - NDCG: 0.7657 - val_loss: 4.9729 - val_NDCG27: 0.6632 - val_NDCG: 0.7775
# Epoch 22/57
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2676 - NDCG27: 0.6565 - NDCG: 0.7673 - val_loss: 4.9728 - val_NDCG27: 0.6923 - val_NDCG: 0.8015
# Epoch 23/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2177 - NDCG27: 0.6554 - NDCG: 0.7649 - val_loss: 4.9756 - val_NDCG27: 0.6871 - val_NDCG: 0.7927
# Epoch 24/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2831 - NDCG27: 0.6588 - NDCG: 0.7687 - val_loss: 4.9700 - val_NDCG27: 0.6866 - val_NDCG: 0.7965
# Epoch 25/57
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2186 - NDCG27: 0.6600 - NDCG: 0.7693 - val_loss: 4.9726 - val_NDCG27: 0.6813 - val_NDCG: 0.7931
# Epoch 26/57
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2872 - NDCG27: 0.6573 - NDCG: 0.7669 - val_loss: 4.9714 - val_NDCG27: 0.6689 - val_NDCG: 0.7863
# Epoch 27/57
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2281 - NDCG27: 0.6596 - NDCG: 0.7687 - val_loss: 4.9674 - val_NDCG27: 0.6821 - val_NDCG: 0.7993
# Epoch 28/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2414 - NDCG27: 0.6571 - NDCG: 0.7669 - val_loss: 4.9660 - val_NDCG27: 0.6846 - val_NDCG: 0.7941
# Epoch 29/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2541 - NDCG27: 0.6581 - NDCG: 0.7679 - val_loss: 4.9676 - val_NDCG27: 0.6865 - val_NDCG: 0.7990
# Epoch 30/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2170 - NDCG27: 0.6582 - NDCG: 0.7663 - val_loss: 4.9691 - val_NDCG27: 0.6801 - val_NDCG: 0.7940
# Epoch 31/57
# 100/100 [==============================] - 1s 9ms/step - loss: 4.2824 - NDCG27: 0.6599 - NDCG: 0.7696 - val_loss: 4.9624 - val_NDCG27: 0.6886 - val_NDCG: 0.7985
# Epoch 32/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2189 - NDCG27: 0.6611 - NDCG: 0.7690 - val_loss: 4.9613 - val_NDCG27: 0.6877 - val_NDCG: 0.8021
# Epoch 33/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2918 - NDCG27: 0.6579 - NDCG: 0.7671 - val_loss: 4.9614 - val_NDCG27: 0.6820 - val_NDCG: 0.7954
# Epoch 34/57
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2167 - NDCG27: 0.6609 - NDCG: 0.7687 - val_loss: 4.9542 - val_NDCG27: 0.6907 - val_NDCG: 0.8034
# Epoch 35/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2455 - NDCG27: 0.6596 - NDCG: 0.7683 - val_loss: 4.9555 - val_NDCG27: 0.6844 - val_NDCG: 0.7949
# Epoch 36/57
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2619 - NDCG27: 0.6597 - NDCG: 0.7689 - val_loss: 4.9543 - val_NDCG27: 0.6932 - val_NDCG: 0.8024
# Epoch 37/57
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2158 - NDCG27: 0.6600 - NDCG: 0.7678 - val_loss: 4.9556 - val_NDCG27: 0.6898 - val_NDCG: 0.8001
# Epoch 38/57
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2891 - NDCG27: 0.6604 - NDCG: 0.7697 - val_loss: 4.9500 - val_NDCG27: 0.6880 - val_NDCG: 0.8000
# Epoch 39/57
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2056 - NDCG27: 0.6625 - NDCG: 0.7700 - val_loss: 4.9508 - val_NDCG27: 0.6875 - val_NDCG: 0.8017
# Epoch 40/57
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2924 - NDCG27: 0.6605 - NDCG: 0.7694 - val_loss: 4.9452 - val_NDCG27: 0.6860 - val_NDCG: 0.7982
# Epoch 41/57
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2267 - NDCG27: 0.6619 - NDCG: 0.7694 - val_loss: 4.9408 - val_NDCG27: 0.6972 - val_NDCG: 0.8070
# Epoch 42/57
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2464 - NDCG27: 0.6596 - NDCG: 0.7680 - val_loss: 4.9412 - val_NDCG27: 0.6901 - val_NDCG: 0.7982
# Epoch 43/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2442 - NDCG27: 0.6617 - NDCG: 0.7695 - val_loss: 4.9358 - val_NDCG27: 0.6935 - val_NDCG: 0.8045
# Epoch 44/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2258 - NDCG27: 0.6592 - NDCG: 0.7670 - val_loss: 4.9407 - val_NDCG27: 0.6904 - val_NDCG: 0.8032
# Epoch 45/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2888 - NDCG27: 0.6611 - NDCG: 0.7695 - val_loss: 4.9340 - val_NDCG27: 0.6893 - val_NDCG: 0.8021
# Epoch 46/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.1985 - NDCG27: 0.6629 - NDCG: 0.7701 - val_loss: 4.9350 - val_NDCG27: 0.6928 - val_NDCG: 0.8040
# Epoch 47/57
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2896 - NDCG27: 0.6592 - NDCG: 0.7677 - val_loss: 4.9356 - val_NDCG27: 0.6922 - val_NDCG: 0.8061
# Epoch 48/57
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2263 - NDCG27: 0.6626 - NDCG: 0.7696 - val_loss: 4.9264 - val_NDCG27: 0.6957 - val_NDCG: 0.8055
# Epoch 49/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2602 - NDCG27: 0.6612 - NDCG: 0.7691 - val_loss: 4.9271 - val_NDCG27: 0.6902 - val_NDCG: 0.8007
# Epoch 50/57
# 100/100 [==============================] - 1s 9ms/step - loss: 4.2450 - NDCG27: 0.6629 - NDCG: 0.7709 - val_loss: 4.9229 - val_NDCG27: 0.6995 - val_NDCG: 0.8090
# Epoch 51/57
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2176 - NDCG27: 0.6603 - NDCG: 0.7676 - val_loss: 4.9290 - val_NDCG27: 0.6795 - val_NDCG: 0.7859
# Epoch 52/57
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2851 - NDCG27: 0.6602 - NDCG: 0.7689 - val_loss: 4.9248 - val_NDCG27: 0.6962 - val_NDCG: 0.8070
# Epoch 53/57
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2032 - NDCG27: 0.6608 - NDCG: 0.7682 - val_loss: 4.9240 - val_NDCG27: 0.6959 - val_NDCG: 0.8056
# Epoch 54/57
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2854 - NDCG27: 0.6619 - NDCG: 0.7700 - val_loss: 4.9281 - val_NDCG27: 0.6769 - val_NDCG: 0.7877
# Epoch 55/57
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2173 - NDCG27: 0.6625 - NDCG: 0.7695 - val_loss: 4.9208 - val_NDCG27: 0.7006 - val_NDCG: 0.8125
# Epoch 56/57
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2847 - NDCG27: 0.6592 - NDCG: 0.7679 - val_loss: 4.9293 - val_NDCG27: 0.6835 - val_NDCG: 0.7892
# Epoch 57/57
# 100/100 [==============================] - 1s 6ms/step - loss: 4.2276 - NDCG27: 0.6618 - NDCG: 0.7696 - val_loss: 4.9236 - val_NDCG27: 0.7021 - val_NDCG: 0.8110

# %%
## Evaluate model performance
fig, ax1 = plt.subplots(figsize = (12,8))
ax1.plot(hyperhistory.history['NDCG27'])
ax1.plot(hyperhistory.history['val_NDCG27'])
ax1.set_title('Model NDCG27')
ax1.set_ylabel('NDCG27')
ax1.set_xlabel('Epoch')
ax1.legend(['Training','Validation'],loc='upper left')

# %% [markdown]
# ### PREDICTIONS AND RANKING CREATION

# %%
# The maximum number of documents per query in the dataset.
# Document lists are padded or truncated to this size. That is because model.predicts accept tensors to predict in bulk
_LIST_SIZE = 108 #For each query we will be taking the max number of docs/companies - 108

test_dataset = create_dataset_from_tfrecords(_VALID_DATA_PATH,
                                             batch_sz=_BATCH_SIZE,
                                             list_sz=_LIST_SIZE,
                                             shuffle=False,
                                             num_epochs=1, 
                                             compression_type="")

predictions = hypermodel.predict(test_dataset,
                                 batch_size=None,
                                 verbose='auto',
                                 steps=None,
                                 callbacks=None)

# %%
#Let's parse the TFRecords in order to obtain the id of each query (DATE) + the list of ids (TICKERS) of the documents (STOCKS) in each query
raw_dataset = tf.data.TFRecordDataset([_VALID_DATA_PATH])

query_docs_list = [] #A list that will be populated with tuples (query_id, list_of_docs)
for raw_record in raw_dataset.take(-1): #take(-1) takes all the records in raw_dataset
    ELWC = input_pb2.ExampleListWithContext()
    v = ELWC.FromString(raw_record.numpy()) #v is composed by v.context and a set of examples in v.examples
    
    query_id = v.context.features.feature['qid'].bytes_list.value[0].decode('UTF-8')
    docs_list = []
    for e in v.examples:
        doc_id = e.features.feature['doc'].bytes_list.value[0].decode('UTF-8')
        docs_list.append(doc_id)
        
    query_docs_list.append((query_id, docs_list))

# %%
predictions_record = [] #List that will contain  the prediction tuples (date, ranking_of_companies)
queries = []
docs_per_query = []
for idx, query_docs in enumerate(query_docs_list):
    query, docs = query_docs
    scores = list(predictions[idx])
    dict_doc_scr = dict(zip(docs, scores))
    sorted_dict = dict(sorted(dict_doc_scr.items(), key=lambda item: item[1], reverse=True))
    queries.append(query)
    docs_per_query.append(list(sorted_dict.keys()))

# %%
result_dict = {'date': queries, 'ranking': docs_per_query}

df = pd.DataFrame.from_dict(result_dict, orient='index')
df = df.transpose()
df.to_csv('ranking_results9.csv', index=False, header=True,  encoding='utf-8')
